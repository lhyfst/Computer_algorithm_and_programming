# %% [raw]
# Use netxworkx to generate one ER network, one small world network, and one scale free network; Calculate and plot the degree distributions for all three networks. (The total vertices N=1000.)

# %%
import matplotlib.pyplot as plt
from networkx import nx

n = 1000 
G = nx.erdos_renyi_graph(n,0.05)

f = plt.figure(figsize=(10,10))
nx.draw(G)
plt.show()



fig, ax = plt.subplots()

x = [i[0] for i in degrees]
y = [i[1] for i in degrees]

num_bins = 50
ax.hist(y, num_bins)

ax.set_xlabel('degree')
ax.set_ylabel('Probability density')
ax.set_title(r'ER Graph')

fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
from networkx import nx

n = 1000 
G = nx.watts_strogatz_graph(n,5,0.05)

f = plt.figure(figsize=(10,10))
nx.draw_circular(G, with_labels=False)
plt.show()



fig, ax = plt.subplots()

x = [i[0] for i in degrees]
y = [i[1] for i in degrees]

num_bins = 50
ax.hist(y, num_bins)

ax.set_xlabel('degree')
ax.set_ylabel('Probability density')
ax.set_title(r'ER Graph')

fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
from networkx import nx

n = 1000
G = nx.scale_free_graph(n)

f = plt.figure(figsize=(10,10))
nx.draw(G)
plt.show()



fig, ax = plt.subplots()

x = [i[0] for i in degrees]
y = [i[1] for i in degrees]

num_bins = 50
ax.hist(y, num_bins)

ax.set_xlabel('degree')
ax.set_ylabel('Probability density')
ax.set_title(r'ER Graph')

fig.tight_layout()
plt.show()

# %%
# Use netxworkx to generate one ER network, one small world network, and one scale free network; 
# Calculate and plot the degree distributions for all three networks. (The total vertices N=1000.)

# ER network
import matplotlib.pyplot as plt
from networkx import nx

n = 1000 
G = nx.erdos_renyi_graph(n,0.05)

f = plt.figure(figsize=(10,10))
nx.draw(G)
plt.show()

fig, ax = plt.subplots()
x = [i[0] for i in degrees]
y = [i[1] for i in degrees]
num_bins = 50
ax.hist(y, num_bins)
ax.set_xlabel('degree')
ax.set_ylabel('Probability density')
ax.set_title(r'ER network')
fig.tight_layout()
plt.show()


# small world network
n = 1000 
G = nx.watts_strogatz_graph(n,5,0.05)

f = plt.figure(figsize=(10,10))
nx.draw_circular(G, with_labels=False)
plt.show()

fig, ax = plt.subplots()
x = [i[0] for i in degrees]
y = [i[1] for i in degrees]
num_bins = 50
ax.hist(y, num_bins)
ax.set_xlabel('degree')
ax.set_ylabel('Probability density')
ax.set_title(r'small world network')
fig.tight_layout()
plt.show()


# one scale free network
n = 1000
G = nx.scale_free_graph(n)

f = plt.figure(figsize=(10,10))
nx.draw(G)
plt.show()

fig, ax = plt.subplots()
x = [i[0] for i in degrees]
y = [i[1] for i in degrees]
num_bins = 50
ax.hist(y, num_bins)
ax.set_xlabel('degree')
ax.set_ylabel('Probability density')
ax.set_title(r'one scale free network')
fig.tight_layout()
plt.show()
